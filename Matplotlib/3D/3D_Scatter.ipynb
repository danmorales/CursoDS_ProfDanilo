# %% [markdown]
# # Matplotlib - Gráfico de linha 3D

# %% [markdown]
# * Criando gráficos de scatter 3D com a biblioteca MatPlotLib
# * @CursoDS_ProfDanilo
# * Prof. Dr. Danilo Morales Teixeira
# * cursods.profdanilo@gmail.com

# %% [markdown]
# * Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Criando variáveis X e Y

# %%
X = np.linspace(-5,5,11)
Y = np.linspace(-5,5,11)

# %% [markdown]
# * Criando variável Z

# %%
Z1 = 2*X**2 - 5*Y**2
Z2 = -2*X**2 + 8*Y**3

# %% [markdown]
# * Gráfico 3D

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(X,Y,Z1)
plt.show()

# %% [markdown]
# * Inserindo nomes nos eixos

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(X,Y,Z1)
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_zlabel('Eixo Z')
plt.tight_layout()
plt.show()

# %% [markdown]
# * Inserindo dois gráficos

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(X,Y,Z1,label='Z1')
ax.scatter(X,Y,Z2,label='Z2')
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_zlabel('Eixo Z')
plt.legend()
plt.tight_layout()
plt.show()
