# %% [markdown]
# # Matplotlib - Gráfico de espalhamento - Parte 1

# %% [markdown]
# * Parte 1: Criando gráficos de scatter com a biblioteca Matplotlib
# * @CursoDS_ProfDanilo
# * Prof. Dr. Danilo Morales Teixeira
# * cursods.profdanilo@gmail.com

# %% [markdown]
# * Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Criando variável X

# %%
X = np.linspace(0,5,11)

# %% [markdown]
# * Criando funções Y(X) e Z(X)

# %%
Y = np.power(X-2,2.0)

# %%
Z = np.exp(X/2.0)

# %% [markdown]
# * Gráfico de Y em função de X

# %%
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# * Inserindo nomes nos eixos

# %%
plt.scatter(X,Y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Inserindo título no gráfico

# %%
plt.scatter(X,Y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X)')
plt.show()

# %% [markdown]
# * Dois gráficos na mesma imagem

# %%
plt.scatter(X,Y)
plt.scatter(X,Z)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.show()

# %% [markdown]
# * Alterando cores

# %%
plt.scatter(X,Y,color='black')
plt.scatter(X,Z,color='red')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.show()

# %% [markdown]
# * Inserindo legenda

# %%
plt.scatter(X,Y,color='black',label='Y(X)')
plt.scatter(X,Z,color='red',label='Z(X)')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.legend()
plt.show()
