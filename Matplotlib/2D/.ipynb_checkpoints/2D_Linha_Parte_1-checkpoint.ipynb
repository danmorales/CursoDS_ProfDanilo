# %% [markdown]
# # Matplotlib - Gráfico de linha - Parte 1

# %% [markdown]
# * Parte 1: Criando gráficos de linha com a biblioteca MatPlotLib
# * @CursoDS_ProfDanilo
# * Prof. Dr. Danilo Morales Teixeira
# * cursods.profdanilo@gmail.com

# %% [markdown]
# * Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Criando variável X

# %%
X = np.linspace(0,5,11)

# %% [markdown]
# * Criando funções Y(X) e Z(X)

# %%
Y = np.power(X-2,2.0)

# %%
Z = np.exp(X/2.0)

# %% [markdown]
# * Gráfico de Y em função de X

# %%
plt.plot(X,Y)
plt.show()

# %% [markdown]
# * Inserindo nomes nos eixos

# %%
plt.plot(X,Y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Inserindo título no gráfico

# %%
plt.plot(X,Y)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X)')
plt.show()

# %% [markdown]
# * Dois gráficos na mesma imagem

# %%
plt.plot(X,Y)
plt.plot(X,Z)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.show()

# %% [markdown]
# * Alterando cores

# %%
plt.plot(X,Y,color='black')
plt.plot(X,Z,color='red')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.show()

# %% [markdown]
# * Inserindo legenda

# %%
plt.plot(X,Y,color='black',label='Y(X)')
plt.plot(X,Z,color='red',label='Z(X)')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Y(X), Z(X)')
plt.legend()
plt.show()
