# %% [markdown]
# # Matplotlib - Gráfico de linha - Parte 2

# %% [markdown]
# * Parte 2: Manipulando eixos dos gráficos
# * @CursoDS_ProfDanilo
# * Prof. Dr. Danilo Morales Teixeira
# * cursods.profdanilo@gmail.com

# %% [markdown]
# * Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Criando variável X

# %%
X = np.linspace(0,5,11)

# %% [markdown]
# * Criando funções Y(X) e Z(X)

# %%
Y = np.power(X-2,2.0)

# %%
Z = np.exp(X/2.0)

# %% [markdown]
# * Gráfico de Y e Z em função de X

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Alterando eixo X

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlim([0,2])
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Alteranco eixo Y

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlim([0,2])
plt.ylim([0,5])
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Invertendo eixo X

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlim([2,0])
plt.ylim([0,5])
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %% [markdown]
# * Rotacionando valores do eixo X

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlim([2,0])
plt.ylim([0,5])
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.xticks(rotation=45)
plt.show()
