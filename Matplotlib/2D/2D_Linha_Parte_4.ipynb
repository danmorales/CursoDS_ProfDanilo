# %% [markdown]
# # Matplotlib - Gráfico de linha - Parte 3

# %% [markdown]
# * Parte 4: Adicionando preenchimento no gráfico
# * @CursoDS_ProfDanilo
# * Prof. Dr. Danilo Morales Teixeira
# * cursods.profdanilo@gmail.com

# %% [markdown]
# * Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * Criando variável X

# %%
X = np.linspace(0,2.0*np.pi,360)

# %% [markdown]
# * Criando funções Y(X) e Z(X)

# %%
Y = np.sin(X)

# %%
Z = np.cos(X)

# %% [markdown]
# * Gráfico de Y e Z em função de X

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()
plt.show()

# %% [markdown]
# * Adicionando preenchimento

# %%
plt.plot(X,Y,label='Y(X)')
plt.fill_between(X,0,np.sin(X))
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()
plt.show()

# %%
plt.plot(X,Y,label='Y(X)')
plt.plot(X,Z,label='Z(X)')
plt.fill_between(X,0,np.sin(X))
plt.fill_between(X,0,np.cos(X))
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()
plt.show()
