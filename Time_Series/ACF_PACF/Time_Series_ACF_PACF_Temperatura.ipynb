# %% [markdown]
# # ACF e PACF

# %% [markdown]
# Determinando a autocorrelação e a autocorrelação parcial

# %% [markdown]
# Utilizaremos uma série temporal da temperatura na cidade australiana de Melbourne

# %% [markdown]
# * Importando biblitecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Lendo CSV

# %%
dados = pd.read_csv('daily-min-temperatures.csv')

# %% [markdown]
# * Exibindo cinco primeiras linhas

# %%
dados.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %% [markdown]
# * Definindo data como indice

# %%
dados['Date'] = pd.to_datetime(dados['Date'])
dados = dados.set_index('Date')

# %% [markdown]
# * Graficando série temporal

# %%
dados.plot()
plt.xticks(rotation=45)
plt.xlabel('Data')
plt.ylabel('Temperatura')
plt.tight_layout()

# %% [markdown]
# * Graficando autocorrelação

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(dados.values,lags=80)
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.show()

# %% [markdown]
# * Alterando range

# %%
plot_acf(dados.values,lags=80)
plt.xlabel('Lag')
plt.ylabel('ACF')
plt.xlim([0,10])
plt.show()

# %% [markdown]
# Encontramos que a lag do ACF tem valor 69

# %% [markdown]
# * Graficando autocorrelação parcial

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(dados.values,lags=80)
plt.xlabel('Lag')
plt.ylabel('PACF')
plt.show()

# %% [markdown]
# * Alterando range

# %%
plot_pacf(dados.values,lags=80)
plt.xlabel('Lag')
plt.ylabel('PACF')
plt.xlim([0,35])
plt.show()

# %% [markdown]
# Encontramos que a PACF tem lag igual a 10
