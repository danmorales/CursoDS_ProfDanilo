# %% [markdown]
# # Modelo Auto Regressivo Média Móvel

# %% [markdown]
# Utilizando modelo ARMA para modelar a série temporal

# %% [markdown]
# Utilizaremos uma série temporal do número de passageiros de uma linha de trem

# %% [markdown]
# * Importando biblitecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * Lendo arquivo CSV

# %%
dados = pd.read_csv('Passageiros.csv')

# %% [markdown]
# Exibindo cinco primeiras linhas

# %%
dados.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %% [markdown]
# * Removendo coluna ID

# %%
dados = dados.drop('ID',axis=1)

# %% [markdown]
# * Definindo data como índice

# %%
dados['Datetime'] = pd.to_datetime(dados['Datetime'])
dados = dados.set_index('Datetime')

# %% [markdown]
# * Número de passageiros diário

# %%
dados =  dados.resample('D').sum()
dados= dados.dropna()

# %% [markdown]
# * Graficando série temporal

# %%
dados.plot()
plt.xticks(rotation=45)
plt.xlabel('Data')
plt.ylabel('Passageiros')
plt.tight_layout()

# %%
t_treino = dados[dados.index<'2014-06-01'].index.values
t_teste = dados[dados.index>='2014-06-01'].index.values
X_treino = dados[dados.index<'2014-06-01'].values
X_teste = dados[dados.index>='2014-06-01'].values

# %% [markdown]
# * Aplicando modelo ARIMA

# %%
from statsmodels.tsa.api import ARIMA

# %%
modelo = ARIMA(X_treino, order=(2,1,1))
resultado = modelo.fit()

# %% [markdown]
# * Coeficientes

# %%
print('Coefficients: %s' % resultado.params)
# Out:
# Coefficients: [ 7.15128775  0.43387807 -0.04010957 -0.97424694]

# %% [markdown]
# * Fazendo predições

# %%
X_pred = resultado.predict(start=len(X_treino), end=len(X_treino)+len(X_teste)-1)

# %% [markdown]
# * Calculando erros

# %%
plt.plot(t_treino,X_treino,label='Treino')
plt.plot(t_teste,X_teste,label='Teste')
plt.plot(t_teste,X_pred,label='Predito')
plt.xticks(rotation=45)
plt.legend()

# %% [markdown]
# * Calculando erros

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(X_teste,X_pred)

# %%
RMSE = np.sqrt(MSE)

# %%
print("RMSE = {:0.2f}".format(RMSE))
# Out:
# RMSE = 7057.03

# %% [markdown]
# * Grid Search

# %%
best = 1e6
i_best = 0
j_best = 0
k_best = 0

for i in range(1,4):
    for j in range(0,3):
        for k in range(0,2):
            modelo = ARIMA(X_treino, order=(i,k,j))
            resultado = modelo.fit()
            AIC = resultado.aic
            X_pred = resultado.predict(start=len(X_treino), end=len(X_treino)+len(X_teste)-1)
            MSE = mean_squared_error(X_teste,X_pred)
            RMSE = np.sqrt(MSE)
            if(RMSE<best):
                best = RMSE
                i_best = i
                j_best = j
                k_best = k
            print("i = {} j = {}, k={},  AIC = {:0.2f} RMSE = {:0.2f}".format(i,j,k,AIC,RMSE))
        
print("Melhor i = {}".format(i_best))
print("Melhor j = {}".format(j_best))
print("Melhor k = {}".format(k_best))
# Out:
# i = 1 j = 0, k=0,  AIC = 15130.64 RMSE = 5810.35
# i = 1 j = 0, k=1,  AIC = 15147.10 RMSE = 7061.93
# i = 1 j = 1, k=0,  AIC = 15089.22 RMSE = 5698.81
# i = 1 j = 1, k=1,  AIC = 14934.58 RMSE = 7057.14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-57846bfe3649> in <module>
#       8         for k in range(0,2):
#       9             modelo = ARIMA(X_treino, order=(i,k,j))
# ---> 10             resultado = modelo.fit()
#      11             AIC = resultado.aic
#      12             X_pred = resultado.predict(start=len(X_treino), end=len(X_treino)+len(X_teste)-1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     983             start_params = array_like(start_params, 'start_params')
#     984         else:  # estimate starting parameters
# --> 985             start_params = self._fit_start_params((k_ar, k_ma, k), method,
#     986                                                   start_ar_lags)
#     987
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     575                 return -self.loglike_css(params)
#     576
# --> 577             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     578             if self.transparams:
#     579                 start_params = self._invtransparams(start_params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     510                     if maxlag >= nobs:
#     511                         maxlag = nobs - 1
# --> 512                     mod = ar_select_order(endog, maxlag, trend='n').model
#     513                     armod = mod.fit()
#     514                 else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py in ar_select_order(endog, maxlag, ic, glob, trend, seasonal, exog, hold_back, period, missing)
#    2331             sel[base_col:base_col + i] = True
#    2332             if not np.any(sel):
# -> 2333                 ics.append((0, ic_no_data()))
#    2334                 continue
#    2335             res = OLS(y, x[:, sel]).fit()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py in ic_no_data()
#    2320                               endog=y,
#    2321                               exog=np.empty((y.shape[0], 0)))
# -> 2322         llf = OLS.loglike(mod, np.empty(0))
#    2323         res = SimpleNamespace(resid=y, nobs=y.shape[0], llf=llf,
#    2324                               df_model=0, k_constant=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py in loglike(self, params, scale)
#     881         nobs2 = self.nobs / 2.0
#     882         nobs = float(self.nobs)
# --> 883         resid = self.endog - np.dot(self.exog, params)
#     884         if hasattr(self, 'offset'):
#     885             resid -= self.offset
#
# KeyboardInterrupt:

# %% [markdown]
# * Melhor modelo tem indices (5,0,2)

# %% [markdown]
# * Aplicando melhor modelo

# %%
modelo = ARIMA(X_treino, order=(5,0,2))
resultado = modelo.fit()
X_pred = resultado.predict(start=len(X_treino), end=len(X_treino)+len(X_teste)-1)

# %%
plt.plot(t_treino,X_treino,label='Treino');
plt.plot(t_teste,X_teste,label='Teste');
plt.plot(t_teste,X_pred,label='Predito');
plt.xticks(rotation=45);
